# %% [markdown]
# #TEMA 2 SSC <br>
# Student: Olarescu Stefan <br>
# Grupa: 342 A3 <br>
#
#
# # Working with structured data in Python using Beautiful Soup

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup as bbb

# %% [markdown]
# Am importat requests si BeautifulSoup pentru a reusi sa extrag date din diferite URL-uri. Datele sunt citite direct de pe URL dar putem stabili si o cale locala unde sa rulam notebook-ul local pe laptopul fiecaruia. De asemenea, doresc sa salvez aceste date in storage-ul meu cu numele cloud-object-storage-so.

# %%
url1='https://altex.ro/aspirator-umed-uscat-black-decker-bxvc30xtde-1600w-30l/cpd/MSPBXVC30XTDE/' 
url2='https://altex.ro/casti-samsung-galaxy-buds-sm-r170nzkarom-true-wireless-bluetooth-in-ear-microfon-negru/cpd/CASR170NZKAR/'
url3='https://altex.ro/casti-skullcandy-indy-s2ssw-m003-true-wireless-bluetooth-in-ear-microfon-negru/cpd/CASINDYBK/'
url4='https://altex.ro/casti-skullcandy-hesh-2-s6hbgy-374-bluetooth-over-ear-microfon-negru/cpd/CASS6HBGY-374/'
url5='https://altex.ro/casti-sony-wh-ch510-bluetooth-on-ear-microfon-albastru/cpd/CASCH510L/'
url6='https://altex.ro/casca-bluetooth-plantronics-explorer-55-black/cpd/CASPLB00118/'
url7='https://altex.ro/casti-jabra-elite-85h-bluetooth-over-ear-microfon-noise-cancelling-bleumarin/cpd/CASELITE85HBLE/'
url8='https://altex.ro/casti-apple-airpods-2-mv7n2zm-a-true-wireless-bluetooth-in-ear-microfon-alb/cpd/CASAIRPODS/'
url9='https://altex.ro/casti-promate-gearpod-is2-cu-fir-in-ear-microfon-negru/cpd/CASGEARPODIS2BK/'
url10='https://altex.ro/casti-jbl-tune-220-tws-true-wireless-bluetooth-in-ear-microfon-negru/cpd/CASJBLT220TWBLK/'

# %% [markdown]
# Am adaugat cateva link-uri cu produsele care ma intereseaza.

# %%
page1 = requests.get(url1) 
page2 = requests.get(url2) 
page3 = requests.get(url3) 
page4 = requests.get(url4) 
page5 = requests.get(url5) 
page6 = requests.get(url6) 
page7 = requests.get(url7) 
page8 = requests.get(url8) 
page9 = requests.get(url9) 
page10 = requests.get(url10)

# %%
soup1 = bbb(page1.content, 'html.parser')
soup2 = bbb(page2.content, 'html.parser')
soup3 = bbb(page3.content, 'html.parser')
soup4 = bbb(page4.content, 'html.parser')
soup5 = bbb(page5.content, 'html.parser')
soup6 = bbb(page6.content, 'html.parser')
soup7 = bbb(page7.content, 'html.parser')
soup8 = bbb(page8.content, 'html.parser')
soup9 = bbb(page9.content, 'html.parser')
soup10 = bbb(page10.content, 'html.parser')

# %% [markdown]
# Am folosit un parser de html pentru a prelua informatiile necesare. "bbb" este un alias stabilit de catre mine pentru a usura munca cu libraria Beautiul Soup ce are rolul de a extrage si analiza documentele de tip HTML si XML.

# %%
print(page1.content)
# Out:
# b'<!DOCTYPE html><html lang="ro"><head><meta charSet="UTF-8" class="next-head"/><meta name="viewport" content="width=device-width, minimum-scale=1 initial-scale=1" class="next-head"/><link rel="icon" href="https://lcdn.altex.ro/render/static/altex/favicon.ico" class="next-head"/><link rel="stylesheet" type="text/css" href="https://lcdn.altex.ro/render/static/baseTailwind.css?c=20200424090830" class="next-head"/><link rel="stylesheet" type="text/css" href="https://lcdn.altex.ro/render/static/altex/css/stylesm.min.css?c=20200424090830" class="next-head"/><link rel="stylesheet" type="text/css" href="https://lcdn.altex.ro/render/static/tailwind.css?c=20200424090830" class="next-head"/><title class="next-head">Aspirator umed/ uscat BLACK &amp; DECKER BXVC30XTDE, 1600W, 30l</title><meta name="description" content="Cumpara acum Aspirator umed/ uscat BLACK &amp; DECKER BXVC30XTDE, 1600W, 30l la pretul de 399.92 lei" class="next-head"/><link rel="canonical" href="https://altex.ro/aspirator-umed-uscat-black-decker-bxvc30xtde-1600w-30l/cpd/MSPBXVC30XTDE/" class="next-head"/><meta name="robots" content="follow, index" class="next-head"/><meta property="og:image" content="https://lcdn.altex.ro/resize/media/catalog/product/B/X/2bd48d28d1c32adea0e55139a4e6434a/BXVC30XTDE_652625a1.jpg" class="next-head"/><script type="application/ld+json">{"@context":"https://schema.org/","@type":"Product","name":"Aspirator umed/ uscat BLACK & DECKER BXVC30XTDE, 1600W, 30l","image":["https://lcdn.altex.ro/media/catalog/product/B/X/BXVC30XTDE_652625a1.jpg"],"sku":"MSPBXVC30XTDE","brand":{"@type":"Thing","name":"BLACK & DECKER"},"mpn":"8016287516891"}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Gradina","item":"https://altex.ro/gradina/cpl/"},{"@type":"ListItem","position":2,"name":"Aspiratoare si suflante","item":"https://altex.ro/aspiratoare-suflante/cpl/"},{"@type":"ListItem","position":3,"name":"Aspirator umed/ uscat BLACK & DECKER BXVC30XTDE, 1600W, 30l","item":"https://altex.ro/aspirator-umed-uscat-black-decker-bxvc30xtde-1600w-30l/cpd/MSPBXVC30XTDE/"}]}</script><link rel="preload" href="https://lcdn.altex.ro/render/_next/static/m1iDUeiW2n0llCaElrj_I/pages/catalog/view.js" as="script"/><link rel="preload" href="https://lcdn.altex.ro/render/_next/static/m1iDUeiW2n0llCaElrj_I/pages/_app.js" as="script"/><link rel="preload" href="https://lcdn.altex.ro/render/_next/static/m1iDUeiW2n0llCaElrj_I/pages/_error.js" as="script"/><link rel="preload" href="https://lcdn.altex.ro/render/_next/static/runtime/webpack-42652fa8b82c329c0559.js" as="script"/><link rel="preload" href="https://lcdn.altex.ro/render/_next/static/chunks/commons.ceae29bc2de522d612f3.js" as="script"/><link rel="preload" href="https://lcdn.altex.ro/render/_next/static/runtime/main-49d53adc6a27c9d14db2.js" as="script"/><style id="__jsx-2454436330">.SessionCosTrigger.jsx-2454436330{padding-left:42px;padding-right:30px;padding-top:15px;padding-bottom:15px;}\n.SessionContTrigger.jsx-2454436330{padding-left:36px;padding-right:30px;padding-top:15px;padding-bottom:15px;}\n.SessionContTrigger.jsx-2454436330 .icon.jsx-2454436330{top:11px;left:10px;}\n.SessionCosTrigger.jsx-2454436330 .icon.jsx-2454436330{top:11px;left:11px;}\n.Session-cosQty.jsx-2454436330{line-height:1rem;top:5px;left:5px;}\n.LoggedInBadge.jsx-2454436330{background-color:#319D10;width:12px;height:12px;bottom:8px;left:24px;}\n.ContWindow.jsx-2454436330{top:43px;}\n.CosWindow.jsx-2454436330{top:43px;left:-40px;}\n@media (max-width:639px){.SessionCosTrigger.jsx-2454436330{padding:5px;width:46px;height:46px;}.SessionCosTrigger.jsx-2454436330 .icon.jsx-2454436330{top:12px;}.Session-cosQty.jsx-2454436330{top:7px;left:2px;}.SessionContTrigger.jsx-2454436330{padding:5px;width:46px;height:46px;}.SessionContTrigger.jsx-2454436330 .icon.jsx-2454436330{top:12px;left:12px;}.LoggedInBadge.jsx-2454436330{bottom:8px;left:25px;}.ContWindow.js ...

# %% [markdown]
# Am verificat ce afiseaza contentul primului link.

# %%
print(soup1)
# Out:
# <!DOCTYPE html>
# <html lang="ro"><head><meta charset="utf-8" class="next-head"/><meta class="next-head" content="width=device-width, minimum-scale=1 initial-scale=1" name="viewport"/><link class="next-head" href="https://lcdn.altex.ro/render/static/altex/favicon.ico" rel="icon"/><link class="next-head" href="https://lcdn.altex.ro/render/static/baseTailwind.css?c=20200424090830" rel="stylesheet" type="text/css"/><link class="next-head" href="https://lcdn.altex.ro/render/static/altex/css/stylesm.min.css?c=20200424090830" rel="stylesheet" type="text/css"/><link class="next-head" href="https://lcdn.altex.ro/render/static/tailwind.css?c=20200424090830" rel="stylesheet" type="text/css"/><title class="next-head">Aspirator umed/ uscat BLACK &amp; DECKER BXVC30XTDE, 1600W, 30l</title><meta class="next-head" content="Cumpara acum Aspirator umed/ uscat BLACK &amp; DECKER BXVC30XTDE, 1600W, 30l la pretul de 399.92 lei" name="description"/><link class="next-head" href="https://altex.ro/aspirator-umed-uscat-black-decker-bxvc30xtde-1600w-30l/cpd/MSPBXVC30XTDE/" rel="canonical"/><meta class="next-head" content="follow, index" name="robots"/><meta class="next-head" content="https://lcdn.altex.ro/resize/media/catalog/product/B/X/2bd48d28d1c32adea0e55139a4e6434a/BXVC30XTDE_652625a1.jpg" property="og:image"/><script type="application/ld+json">{"@context":"https://schema.org/","@type":"Product","name":"Aspirator umed/ uscat BLACK & DECKER BXVC30XTDE, 1600W, 30l","image":["https://lcdn.altex.ro/media/catalog/product/B/X/BXVC30XTDE_652625a1.jpg"],"sku":"MSPBXVC30XTDE","brand":{"@type":"Thing","name":"BLACK & DECKER"},"mpn":"8016287516891"}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Gradina","item":"https://altex.ro/gradina/cpl/"},{"@type":"ListItem","position":2,"name":"Aspiratoare si suflante","item":"https://altex.ro/aspiratoare-suflante/cpl/"},{"@type":"ListItem","position":3,"name":"Aspirator umed/ uscat BLACK & DECKER BXVC30XTDE, 1600W, 30l","item":"https://altex.ro/aspirator-umed-uscat-black-decker-bxvc30xtde-1600w-30l/cpd/MSPBXVC30XTDE/"}]}</script><link as="script" href="https://lcdn.altex.ro/render/_next/static/m1iDUeiW2n0llCaElrj_I/pages/catalog/view.js" rel="preload"/><link as="script" href="https://lcdn.altex.ro/render/_next/static/m1iDUeiW2n0llCaElrj_I/pages/_app.js" rel="preload"/><link as="script" href="https://lcdn.altex.ro/render/_next/static/m1iDUeiW2n0llCaElrj_I/pages/_error.js" rel="preload"/><link as="script" href="https://lcdn.altex.ro/render/_next/static/runtime/webpack-42652fa8b82c329c0559.js" rel="preload"/><link as="script" href="https://lcdn.altex.ro/render/_next/static/chunks/commons.ceae29bc2de522d612f3.js" rel="preload"/><link as="script" href="https://lcdn.altex.ro/render/_next/static/runtime/main-49d53adc6a27c9d14db2.js" rel="preload"/><style id="__jsx-2454436330">.SessionCosTrigger.jsx-2454436330{padding-left:42px;padding-right:30px;padding-top:15px;padding-bottom:15px;}
# .SessionContTrigger.jsx-2454436330{padding-left:36px;padding-right:30px;padding-top:15px;padding-bottom:15px;}
# .SessionContTrigger.jsx-2454436330 .icon.jsx-2454436330{top:11px;left:10px;}
# .SessionCosTrigger.jsx-2454436330 .icon.jsx-2454436330{top:11px;left:11px;}
# .Session-cosQty.jsx-2454436330{line-height:1rem;top:5px;left:5px;}
# .LoggedInBadge.jsx-2454436330{background-color:#319D10;width:12px;height:12px;bottom:8px;left:24px;}
# .ContWindow.jsx-2454436330{top:43px;}
# .CosWindow.jsx-2454436330{top:43px;left:-40px;}
# @media (max-width:639px){.SessionCosTrigger.jsx-2454436330{padding:5px;width:46px;height:46px;}.SessionCosTrigger.jsx-2454436330 .icon.jsx-2454436330{top:12px;}.Session-cosQty.jsx-2454436330{top:7px;left:2px;}.SessionContTrigger.jsx-2454436330{padding:5px;width:46px;height:46px;}.SessionContTrigger.jsx-2454436330 .icon.jsx-2454436330{top:12px;left:12px;}.LoggedInBadge.jsx-2454436330{bottom:8px;left:25px;}.ContWindow.jsx-2454436330{left:40px;top:45px;}.CosWindow.jsx-2454436330{left:20px;top:45px;}}
# @media (min-width:721px) and (max-width:768px){.SessionComponent.jsx-2454436330{margin-top:.5rem;}}</style><style id="__jsx-1670790912">@media (min-width:1021px){.SearchInputComponent.jsx-1670790912{width:400px;}}
# .loader.jsx-1670790912{display:block;left:auto;right:10px;opacity:0;-webkit-transition:opacity 0.3s ease-out;transition:opacity 0.3s ease-out;}</style><style id="__jsx-4236386959">.MobileMenu.jsx-4236386959{position:absolute;top:45px;left:0px;right:40px;z-index:2;}
# @media (min-width:640px){.MobileMenu.jsx-4236386959{right:40%;}}
# @media (min-width:721px){.MobileMenu.jsx-4236386959{top:61px;right:50%;}}</style><style id="__jsx-3093111492">.MobileMenuIcon.jsx-3093111492{height:46px;padding:14px 10px;}
# .MobileMenuIconContainer.jsx-3093111492{height:46px;min-width:42px;}
# @media (min-width:721px){.MobileMenuIconContainer.jsx-3093111492{min-width:61px;height:53px;}.MobileMenuIcon.jsx-3093111492{height:54px;padding-left:20px;padding-right:20px;padding-top:9px;padding-bottom:19px;}}
# @media (min-width:721px) and (max-width:768px){.MobileMenuIconContainer.jsx-3093111492{margin-top:.5rem;}}</style><style id="__jsx-2108482727">.gallery-container.jsx-18812759:focus{outline:none;}</style><style id="__jsx-2903429241">.gallery .slick-list{cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;}
# .lightbox-content .slick-list{cursor:default;}
# .lightbox-content .gallery-container{cursor:-webkit-zoom-out;cursor:-moz-zoom-out;cursor:zoom-out;}</style><meta content="1oNjMk-99XnSHyUxaE9qBb4ONmU-i-Es_FieV6CZ7rI" name="google-site-verification"/><meta content="w95cxxm-ZizZ2pgO-Ts5LWL5MJDc962GSEQDC1PreFU" name="google-site-verification"/><meta content="kiU4EMwNIr9aw4OSL_SJU72Vgda8NZArIxGBgO8uktg" name="google-site-verification"/><script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-PSQXTDH');
#
#         window.dataLayer.push({
#           environment: "altex"
#         });
#       </script></head><body><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PSQXTDH" style="display:none;visibility:hidden" width="0"></iframe></noscript><noscript><div class="Alert Alert--error u-border-radius-0 u-text-align-center u-border-b-solid"><div class="u-container"><strong>JavaScript pare a fi dezactivat in browser-ul dumneavoastra.</strong><br/>Trebuie sa aveti JavaScript activat in browser-ul dumneavoastra pentru a putea utiliza acest site.</div></div></noscript><div id="__next"><div class="u-border-b-solid" style="line-height:20px;text-align:center;font-size:14px"><a class="text-red-brand" href="https://altex.ro/program-special/" style="display:block;padding:5px;_color:#fff">Ramanem deschisi pentru tine! Vezi programul celui mai apropiat magazin.</a></div><div class="jsx-3093111492 relative" style="z-index:104"><div class="jsx-3093111492 Header pt-0 md:pt-2 pb-0 lg:pb-6"><div class="jsx-3093111492 u-container"><div class="jsx-3093111492 u-container-reset"><p class="jsx-3093111492 mt-0 mb-4 p-0 hidden lg:block"><span class="text-black"><strong>Cel mai mic pret din Romania!</strong> Daca gasesti in alta parte mai ieftin primesti de <span class="text-red-brand"><a href="/suport-clienti/servicii-2x-diferenta/">doua ori diferenta</a></span>.</span></p><div class="jsx-3093111492 u-clearfix relative"><div class="jsx-3093111492 MobileMenuIconContainer float-left block lg:hidden"><button class="jsx-3093111492 MobileMenuIcon absolute appearance-none focus:outline-none text-black rounded-t border border-b-0 border-transparent" id="MobileMenuTriggerButton" style="background-color:transparent;z-index:3"><div class="jsx-3093111492 pointer-events-none text-black"><svg class="fill-current" height="16px" version="1.1" viewbox="0 0 19 16" width="19px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><rect height="2" rx="1" width="19" x="0" y="7"></rect><rect height="2" rx="1" width="19" x="0" y="14"></rect><rect height="2" rx="1" width="19" x="0" y="0"></rect></g></svg></div></button></div><div class="u-space-mr-15 u-float-left mb-2 lg:mb-0 ml-2 lg:ml-0 mt-2 md:mt-0"><a class="Header-logo" href="/home/" title="Electronice si electrocasnice - 2x Diferenta*"><strong>Electronice si electrocasnice - 2x Diferenta*</strong></a></div><div class="jsx-2454436330 SessionComponent clearfix float-right static sm:relative md:mb-2 lg:mb-0"><div class="jsx-2454436330 float-left border-r text-black"><a class="jsx-2454436330 SessionContTrigger text-usm font-bold block relative leading-none border border-b-0 rounded rounded-b-none border-transparent" href="https://altex.ro/cont/" style="z-index:0;background-color:transparent"><div _style="[object Object]" class="jsx-2454436330 absolute icon"><svg class="fill-current" height="20px" version="1.1" viewbox="0 0 17 17" width="20px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><path _style="[object Object]" d="M8.5,0.240966797 C11.3994949,0.240966797 13.75,2.59147186 13.75,5.4909668 C13.75,6.96521 13.1423483,8.29752853 12.1638429,9.25112426 L13,9.25 C15.0710678,9.25 16.75,10.9289322 16.75,13 L16.75,14.9968607 C16.75,15.963359 15.9664983,16.7468598 14.9988246,16.7468598 L1.99451486,16.7061052 C1.03016268,16.7030825 0.25,15.9204707 0.25,14.9561138 L0.25,12.9764922 C0.25,10.9184074 1.91840737,9.25 3.97649215,9.25 L4.83615711,9.25112426 C3.85765174,8.29752853 3.25,6.96521 3.25,5.4909668 C3.25,2.59147186 5.60050506,0.240966797 8.5,0.240966797 Z M13,10.75 L3.97649215,10.75 C2.74683449,10.75 1.75,11.7468345 1.75,12.9764922 L1.75,14.9561138 C1.75,15.0938791 1.86145181,15.2056807 1.99921641,15.2061125 L14.998041,15.2468567 L15.0573227,15.240258 C15.1677666,15.2143475 15.25,15.1152074 15.25,14.9968607 L15.25,13 C15.25,11.7573593 14.2426407,10.75 13,10.75 Z M8.5,1.7409668 C6.42893219,1.7409668 4.75,3.41989899 4.75,5.4909668 C4.75,7.56203461 6.42893219,9. ...
# <div class="Services-row">
# <a class="Services-item Services-item-transport" href="/termeni-conditii-livrare/pag/">
# <div class="Services-icon"></div>
# <div class="Services-content">
# <strong class="u-textUppercase">Transport</strong><br/>
#                 Pana la usa ta
#             </div>
# </a>
# <a class="Services-item Services-item-retur" href="/renuntarea-cumparare/pag/">
# <div class="Services-icon"></div>
# <div class="Services-content">
# <strong class="u-textUppercase">Returneaza produsul</strong><br/>
#                 Te-ai razgandit?
#             </div>
# </a>
# <a class="Services-item Services-item-diferenta" href="/altex-dublul-diferentei-online/pag/">
# <div class="Services-icon"></div>
# <div class="Services-content">
# <strong class="u-textUppercase">De 2X diferenta</strong><br/>
#                 Daca gasesti in alta parte mai ieftin, primesti 2x diferenta
#             </div>
# </a>
# <a class="Services-item Services-item-garantie" href="/extragarantie/pag/">
# <div class="Services-icon"></div>
# <div class="Services-content">
# <strong class="u-textUppercase">Extragarantia</strong><br/>
#                 Protejeaza-ti investitia!
#             </div>
# </a>
# </div>
# </div></div></div></div></main></div><div class="Footer"><div class="bg-gray-lighter"><div class="u-container"><div class=""><div class="flex content-center items-center u-space-pt-10 u-space-pb-10"><div class="mr-2 flex-none clearfix"><a class="block float-left mr-2 bg-white rounded p-1 mb-1 mt-1" href="https://altex.ro/best-buy-it-electrocasnice-numarul-unu-romania-2019/pag/"><img alt="" src="https://lcdn.altex.ro/best buy/bba_romania_2019_altex.eps_dfe67807.png"/></a><a class="block float-left mr-2 bg-white rounded p-1 mb-1 mt-1" href="https://altex.ro/best-buy-it-electrocasnice-numarul-unu-romania-2019/pag/"><img alt="" src="https://lcdn.altex.ro/best buy/bba_romania_2019_altex1.eps_5068cf38.png"/></a></div><div class="flex-initial"><p class="mb-0 mt-0"><strong>Cel mai bun raport calitate-pret.</strong></p><p class="mb-0 mt-0">Conform sondajului Best Buy Award 2019/2020 efectuat de organizatia iCertias.</p></div></div></div></div></div><div class="u-container"><div class="u-grid u-border-b-solid u-space-pt-20 u-space-pb-20"><div class="lg-u-size-3of12 lg-u-space-p-5 omd-u-float-left"><div class="Footer-column"><input class="Footer-input" id="footer-column-0" type="checkbox"/><label class="Footer-label u-heading-h4 u-space-mt-5" for="footer-column-0">Companie</label><h4 class="u-space-mt-5 ulg-u-display-none">Companie</h4><div class="my-4 w-8 bg-secondary hidden lg:block" style="height:3px"></div><div class="Footer-list"><a class="u-space-mb-5" href="https://altex.ro/despre-noi/pag/">Despre noi</a><a class="u-space-mb-5" href="https://altex.ro/cariere/">Cariere</a><a class="u-space-mb-5" href="https://altex.ro/noutati-recomandari/pag/">Altex recomanda</a><a class="u-space-mb-5" href="https://altex.ro/harta-site/">Categorii produse</a><a class="u-space-mb-5" href="http://afiliere.altex.ro/">Afiliere Altex</a><a class="u-space-mb-5" href="https://altex.ro/ecotic/pag/">Protectia mediului</a><a class="u-space-mb-5" href="https://altex.ro/vanzari-corporate/pag/">Vanzari corporate</a><a class="u-space-mb-5" href="https://altex.ro/tax-free/pag/">Tax free</a></div></div></div><div class="lg-u-size-3of12 lg-u-space-p-5 omd-u-float-left"><div class="Footer-column"><input class="Footer-input" id="footer-column-1" type="checkbox"/><label class="Footer-label u-heading-h4 u-space-mt-5" for="footer-column-1">Suport clienti</label><h4 class="u-space-mt-5 ulg-u-display-none">Suport clienti</h4><div class="my-4 w-8 bg-secondary hidden lg:block" style="height:3px"></div><div class="Footer-list"><a class="u-space-mb-5" href="https://altex.ro/suport-clienti/">Articole suport</a><a class="u-space-mb-5" href="https://altex.ro/contact/">Contact</a><a class="u-space-mb-5" href="https://altex.ro/cont/retururi/">Returneaza produse</a><a class="u-space-mb-5" href="https://altex.ro/magazine/">Reteaua de magazine Altex</a></div></div></div><div class="lg-u-size-3of12 lg-u-space-p-5 omd-u-float-left"><div class="Footer-column"><input class="Footer-input" id="footer-column-2" type="checkbox"/><label class="Footer-label u-heading-h4 u-space-mt-5" for="footer-column-2">Informatii legale</label><h4 class="u-space-mt-5 ulg-u-display-none">Informatii legale</h4><div class="my-4 w-8 bg-secondary hidden lg:block" style="height:3px"></div><div class="Footer-list"><a class="u-space-mb-5" href="https://altex.ro/termeni-conditii/pag/">Termeni si conditii</a><a class="u-space-mb-5" href="https://altex.ro/politica-utilizare-cookie/pag/">Politica cookie-uri</a><a class="u-space-mb-5" href="https://altex.ro/informatii-privind-deee/pag/">Informatii privind DEEE</a><a class="u-space-mb-5" href="http://www.anpc.gov.ro/">A.N.P.C.</a><a class="u-space-mb-5" href="https://altex.ro/protectia-datelor-caracter-personal/pag/">Protectia datelor cu caracter personal</a><a class="u-space-mb-5" href="https://ec.europa.eu/consumers/odr">ODR</a></div></div></div><div class="lg-u-size-3of12 lg-u-space-p-5 omd-u-float-left"><div class="Footer-column ulg-u-border-none"><input class="Foote ...

# %% [markdown]
# Dupa o prima parsare utilizand BeautifulSoup, contentul arata mult mai bine.

# %%
value1 = soup1.find("div", {"class":"Price-current"})
value2 = soup1.find("div", {"class":"my-0 lg:my-3"})

value3 = soup2.find("div", {"class":"Price-current"})
value4 = soup2.find("div", {"class":"my-0 lg:my-3"})

value5 = soup3.find("div", {"class":"Price-current"})
value6 = soup3.find("div", {"class":"my-0 lg:my-3"})

value7 = soup4.find("div", {"class":"Price-current"})
value8 = soup4.find("div", {"class":"my-0 lg:my-3"})

value9 = soup5.find("div", {"class":"Price-current"})
value10 = soup5.find("div", {"class":"my-0 lg:my-3"})


value11 = soup6.find("div", {"class":"Price-current"})
value12 = soup6.find("div", {"class":"my-0 lg:my-3"})

value13 = soup7.find("div", {"class":"Price-current"})
value14 = soup7.find("div", {"class":"my-0 lg:my-3"})

value15 = soup8.find("div", {"class":"Price-current"})
value16 = soup8.find("div", {"class":"my-0 lg:my-3"})

value17 = soup9.find("div", {"class":"Price-current"})
value18 = soup9.find("div", {"class":"my-0 lg:my-3"})

value19 = soup10.find("div", {"class":"Price-current"})
value20 = soup10.find("div", {"class":"my-0 lg:my-3"})

# %% [markdown]
# Am extras numele produsului si pretul acestuia.

# %%
print(value1.text)
print(value2.text)
print(value3.text)
print(value4.text)
print(value5.text)
print(value6.text)
print(value7.text)
print(value8.text)
print(value9.text)
print(value10.text)

print(value11.text)
print(value12.text)
print(value13.text)
print(value14.text)
print(value15.text)
print(value16.text)
print(value17.text)
print(value18.text)
print(value19.text)
print(value20.text)
# Out:
# 399,92lei
# Aspirator umed/ uscat BLACK & DECKER BXVC30XTDE, 1600W, 30l
# 497,99lei
# Casti SAMSUNG Galaxy Buds SM-R170NZKAROM, True Wireless Bluetooth, In-Ear, Microfon, negru
# 345,79lei
# Casti SKULLCANDY Indy S2SSW-M003, True Wireless Bluetooth, In-Ear, Microfon, negru
# 199,95lei
# Casti SKULLCANDY Hesh 2 S6HBGY-374, Bluetooth, Over-Ear, Microfon, negru
# 169,99lei
# Casti SONY WH-CH510, Bluetooth, On-Ear, Microfon, albastru
# 119,99lei
# Casca Bluetooth PLANTRONICS Explorer 55, Black
# 1.199,99lei
# Casti JABRA Elite 85h, Bluetooth, Over-Ear, Microfon, Noise Cancelling, bleumarin
# 729,99lei
# Casti APPLE AirPods 2 MV7N2ZM/A, True Wireless Bluetooth, In-Ear, Microfon, alb
# 22,49lei
# Casti PROMATE gearPod-iS2, Cu Fir, In-Ear, Microfon, negru
# 479,99lei
# Casti JBL Tune 220 TWS, True wireless Bluetooth, In-ear, Microfon, negru

# %% [markdown]
# Am afisat aceste rezultate si ulterior am creat un grafic.

# %%
data = {'Produs':       ['Casti PIONEER SE-E3','Casti SAMSUNG SM-R170NZKAROM','Casti SKULLCANDY Indy S2SSW-M003','Casti SKULLCANDY Hesh 2 S6HBGY-374','Casti SONY WH-CH510','Casti Plantronics explorer 55','Casti JABRA Elite 58h','Casti APPLE AirPods 2','Casti PROMATE gearPod-iS2','Casti JBL Tune 220 TWS'],
        'Pret': [value1.text, value3.text, value5.text, value7.text, value9.text, value11.text, value13.text, value15.text, value17.text, value19.text ]}
produse = pd.DataFrame(data)

produse
# Out:
#                                Produs         Pret
# 0                 Casti PIONEER SE-E3    399,92lei
# 1        Casti SAMSUNG SM-R170NZKAROM    497,99lei
# 2    Casti SKULLCANDY Indy S2SSW-M003    345,79lei
# 3  Casti SKULLCANDY Hesh 2 S6HBGY-374    199,95lei
# 4                 Casti SONY WH-CH510    169,99lei
# 5       Casti Plantronics explorer 55    119,99lei
# 6               Casti JABRA Elite 58h  1.199,99lei
# 7               Casti APPLE AirPods 2    729,99lei
# 8           Casti PROMATE gearPod-iS2     22,49lei
# 9              Casti JBL Tune 220 TWS    479,99lei

# %% [markdown]
# Am salvat tabelul ca si dataframe si ulterior l-am salvat in format csv si in format excel (extensia xlsx).

# %%
import pandas as pd

data = {'Produs':       ['Casti PIONEER SE-E3','Casti SAMSUNG SM-R170NZKAROM','Casti SKULLCANDY Indy S2SSW-M003','Casti SKULLCANDY Hesh 2 S6HBGY-374','Casti SONY WH-CH510','Casti Plantronics explorer 55','Casti JABRA Elite 58h','Casti APPLE AirPods 2','Casti PROMATE gearPod-iS2','Casti JBL Tune 220 TWS'],
        'Pret': [value1.text, value3.text, value5.text, value7.text, value9.text, value11.text, value13.text, value15.text, value17.text, value19.text ]}

df = pd.DataFrame(data, columns= ['Produs', 'Pret'])

print (df)

#df.to_csv(r'data.csv', index = False)

from IPython.display import FileLink, FileLinks

df.to_csv(r"data.csv", index=False)
df.to_excel(r"data.xlsx", index=False)
# Out:
#                                Produs         Pret
# 0                 Casti PIONEER SE-E3    399,92lei
# 1        Casti SAMSUNG SM-R170NZKAROM    497,99lei
# 2    Casti SKULLCANDY Indy S2SSW-M003    345,79lei
# 3  Casti SKULLCANDY Hesh 2 S6HBGY-374    199,95lei
# 4                 Casti SONY WH-CH510    169,99lei
# 5       Casti Plantronics explorer 55    119,99lei
# 6               Casti JABRA Elite 58h  1.199,99lei
# 7               Casti APPLE AirPods 2    729,99lei
# 8           Casti PROMATE gearPod-iS2     22,49lei
# 9              Casti JBL Tune 220 TWS    479,99lei
